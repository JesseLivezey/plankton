# %%
import os, sys
from scipy.misc import imread, imsave
from scipy.ndimage.interpolation import rotate
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import mixture
np.random.seed(1)

# %%
filedir = '24234.jpg'

# %%
orig_img = imread(filedir)

# %%
nimg = 1. - orig_img/255.
#nimg
#print nimg.shape
pts = np.array(np.where(nimg >= np.median(nimg[nimg>0.])))
#now making new variable where origin corresponds to center of the image.
xy_pts = np.zeros_like(pts, dtype='float')
xy_pts[0] = pts[1] - nimg.shape[1]/2.
xy_pts[1] = nimg.shape[0]/2. - pts[0]

# %%
g = mixture.GMM(n_components=1, covariance_type = 'full')

# %%
g.fit(xy_pts.T)
# Out:
# GMM(covariance_type='full', init_params='wmc', min_covar=0.001,
#   n_components=1, n_init=1, n_iter=100, params='wmc', random_state=None,
#   thresh=0.01)

# %%
gmean = g.means_
gcov = g.covars_

# %%
#have to rotate first because every now and then the shift(roll function) 
#causes a pacman type feature on the other side of the image

# %%
rad_angleRot = (360-orig_angle)*np.pi/180.
rotMatrix = np.array([[np.cos(rad_angleRot), -np.sin(rad_angleRot)], 
                         [np.sin(rad_angleRot),  np.cos(rad_angleRot)]])

rotxy_pts = np.dot(rotMatrix,xy_pts)

# %%
g.fit(rotxy_pts.T)
# Out:
# GMM(covariance_type='full', init_params='wmc', min_covar=0.001,
#   n_components=1, n_init=1, n_iter=100, params='wmc', random_state=None,
#   thresh=0.01)

# %%
gmean = g.means_

# %%
sroimg = np.roll(roimg,int(gmean[0,0]),0)
sroimg = np.roll(sroimg,int(gmean[0,1]),1)
plt.imshow(sroimg)

# %%
srotxy_pts = np.zeros_like(rotxy_pts)

# %%
srotxy_pts[0,:] = rotxy_pts[0,:]-int(gmean[0,0])
srotxy_pts[1,:] = rotxy_pts[1,:]-int(gmean[0,1])

# %%
fsroimg = sroimg

# %%
if np.sum(srotxy_pts[0,:]**3) < 0:
    fsroimg = fsroimg[:,::-1]
    #print 'flip across y axis'
if np.sum(srotxy_pts[1,:]**3) < 0:
    fsroimg = fsroimg[::-1,:]
    #print 'flip across x axis'

# %% [raw]
# #old test code
# g.fit(srotxy_pts.T)
# print g.means_

# %%
plt.imshow(fsroimg)

# %%
plt.imshow(fsroimg)

# %%
plt.imshow(fsroimg)

# %%
plt.imshow(fsroimg)

# %%
plt.imshow(fsroimg)
